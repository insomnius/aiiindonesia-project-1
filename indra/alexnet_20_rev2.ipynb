# %% [markdown]
# # Alexnet 20 Epoch, training 80%, testing 20%
# # Learning Rate 0.00001, Dropout 0.3

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
from PIL import Image
import pandas as pd
import os
import time
import matplotlib.pyplot as plt

# Define AlexNet model for binary classification with dropout
class AlexNetBinary(nn.Module):
    def __init__(self, num_classes=1):
        super(AlexNetBinary, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),  # Add dropout
            nn.Linear(256 * 6 * 6, 2048),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),  # Add dropout
            nn.Linear(2048, 2048),
            nn.ReLU(inplace=True),
#            nn.Dropout(0.3),  # Add dropout
#            nn.Linear(2048, 2048),  # Additional fully connected layer
#            nn.ReLU(inplace=True),  # Additional ReLU activation
            nn.Linear(2048, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Define dataset class
class CustomDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.dataframe = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 0])
        image = Image.open(img_name)
        label = int(self.dataframe.iloc[idx, 1])
        if label == -1:
            label = 0  # Change label -1 to 0 for consistency in the model
        if self.transform:
            image = self.transform(image)
        return image, label

# Load CSV file and define dataset
csv_file = 'clean_attribute_indra.csv'
root_dir = 'Images/'
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.RandomRotation(25),  # Augmentation: Random rotation
    transforms.RandomHorizontalFlip(),  # Augmentation: Random horizontal flip
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])
dataset = CustomDataset(csv_file=csv_file, root_dir=root_dir, transform=transform)

# Split dataset into train, validation, and test sets
indices = list(range(len(dataset)))
train_indices, test_indices = train_test_split(indices, test_size=0.2, random_state=50)
train_dataset = Subset(dataset, train_indices)
test_dataset = Subset(dataset, test_indices)

# Create data loaders for train and test sets
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Initialize the model, optimizer, and loss function
model = AlexNetBinary()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.00001)  # Lower learning rate
criterion = nn.BCEWithLogitsLoss()

# Training the model with validation
num_epochs = 20
train_loss_list = []
train_accuracy_list = []
val_loss_list = []
val_accuracy_list = []

# Initialize variables for early stopping
best_val_loss = float('inf')  # Set initial best validation loss to infinity
patience = 5  # Set patience parameter for early stopping
counter = 0  # Initialize counter for early stopping

for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_train_loss = 0.0
    correct_train = 0
    total_train = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.float().unsqueeze(1).to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_train_loss += loss.item()
        predicted_train = torch.round(torch.sigmoid(outputs))
        total_train += labels.size(0)
        correct_train += (predicted_train == labels).sum().item()
    
    train_loss_list.append(running_train_loss / len(train_loader))
    train_accuracy_list.append((correct_train / total_train) * 100)
    
    # Evaluate the model on test set
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.float().unsqueeze(1).to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            predicted_val = torch.round(torch.sigmoid(outputs))
            total_val += labels.size(0)
            correct_val += (predicted_val == labels).sum().item()
    
    val_loss_list.append(val_loss / len(test_loader))
    val_accuracy_list.append((correct_val / total_val) * 100)
    
    end_time = time.time()
    epoch_time = end_time - start_time
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {train_loss_list[-1]:.4f}, Train Accuracy: {train_accuracy_list[-1]:.2f}%, '
          f'Validation Loss: {val_loss_list[-1]:.4f}, Validation Accuracy: {val_accuracy_list[-1]:.2f}%, '
          f'Time per Epoch: {epoch_time:.2f} seconds')
    
# Plotting
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss', color='blue')
plt.plot(val_loss_list, label='Validation Loss', color='orange')
plt.title('Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracy_list, label='Train Accuracy', color='blue')
plt.plot(val_accuracy_list, label='Validation Accuracy', color='orange')
plt.title('Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Evaluate the model on test set
model.eval()
test_correct = 0
test_total = 0
test_loss = 0.0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.float().unsqueeze(1).to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        predicted = torch.round(torch.sigmoid(outputs))
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

print('Test Loss: {:.4f}, Test Accuracy: {:.2f}%'.format(test_loss / len(test_loader), (test_correct / test_total) * 100))

# Save the model
torch.save(model.state_dict(), 'alexnet_custom_20_epoch_v2.pth')
# Out:
# Epoch [1/20], Train Loss: 0.6803, Train Accuracy: 58.50%, Validation Loss: 0.6692, Validation Accuracy: 60.60%, Time per Epoch: 41.94 seconds
# Epoch [2/20], Train Loss: 0.6566, Train Accuracy: 60.52%, Validation Loss: 0.5999, Validation Accuracy: 66.90%, Time per Epoch: 41.01 seconds
# Epoch [3/20], Train Loss: 0.5759, Train Accuracy: 69.60%, Validation Loss: 0.5252, Validation Accuracy: 73.80%, Time per Epoch: 41.44 seconds
# Epoch [4/20], Train Loss: 0.5222, Train Accuracy: 74.15%, Validation Loss: 0.5110, Validation Accuracy: 74.10%, Time per Epoch: 41.41 seconds
# Epoch [5/20], Train Loss: 0.4840, Train Accuracy: 76.50%, Validation Loss: 0.5030, Validation Accuracy: 74.10%, Time per Epoch: 41.98 seconds
# Epoch [6/20], Train Loss: 0.4684, Train Accuracy: 77.53%, Validation Loss: 0.4445, Validation Accuracy: 80.00%, Time per Epoch: 41.64 seconds
# Epoch [7/20], Train Loss: 0.4332, Train Accuracy: 79.62%, Validation Loss: 0.4170, Validation Accuracy: 82.20%, Time per Epoch: 40.28 seconds
# Epoch [8/20], Train Loss: 0.3992, Train Accuracy: 82.12%, Validation Loss: 0.3838, Validation Accuracy: 83.10%, Time per Epoch: 44.08 seconds
# Epoch [9/20], Train Loss: 0.3764, Train Accuracy: 83.55%, Validation Loss: 0.3496, Validation Accuracy: 84.40%, Time per Epoch: 46.69 seconds
# Epoch [10/20], Train Loss: 0.3473, Train Accuracy: 85.15%, Validation Loss: 0.3182, Validation Accuracy: 85.90%, Time per Epoch: 46.61 seconds
# Epoch [11/20], Train Loss: 0.3158, Train Accuracy: 86.83%, Validation Loss: 0.3079, Validation Accuracy: 85.80%, Time per Epoch: 44.02 seconds
# Epoch [12/20], Train Loss: 0.2883, Train Accuracy: 88.02%, Validation Loss: 0.2917, Validation Accuracy: 86.80%, Time per Epoch: 41.73 seconds
# Epoch [13/20], Train Loss: 0.2804, Train Accuracy: 88.65%, Validation Loss: 0.2643, Validation Accuracy: 88.60%, Time per Epoch: 41.33 seconds
# Epoch [14/20], Train Loss: 0.2534, Train Accuracy: 89.60%, Validation Loss: 0.2488, Validation Accuracy: 89.40%, Time per Epoch: 47.00 seconds
# Epoch [15/20], Train Loss: 0.2511, Train Accuracy: 89.80%, Validation Loss: 0.2411, Validation Accuracy: 89.40%, Time per Epoch: 47.60 seconds
# Epoch [16/20], Train Loss: 0.2361, Train Accuracy: 90.10%, Validation Loss: 0.2187, Validation Accuracy: 90.90%, Time per Epoch: 45.21 seconds
# Epoch [17/20], Train Loss: 0.2213, Train Accuracy: 90.92%, Validation Loss: 0.2539, Validation Accuracy: 88.80%, Time per Epoch: 41.72 seconds
# Epoch [18/20], Train Loss: 0.2142, Train Accuracy: 91.07%, Validation Loss: 0.2176, Validation Accuracy: 90.50%, Time per Epoch: 40.33 seconds
# Epoch [19/20], Train Loss: 0.2071, Train Accuracy: 91.70%, Validation Loss: 0.1907, Validation Accuracy: 91.60%, Time per Epoch: 45.82 seconds
# Epoch [20/20], Train Loss: 0.2030, Train Accuracy: 91.83%, Validation Loss: 0.2073, Validation Accuracy: 91.30%, Time per Epoch: 47.20 seconds
# Test Loss: 0.2059, Test Accuracy: 91.20%

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt

class AlexNetBinary(nn.Module):
    def __init__(self, num_classes=1):
        super(AlexNetBinary, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.3),  # Add dropout
            nn.Linear(256 * 6 * 6, 2048),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),  # Add dropout
            nn.Linear(2048, 2048),
            nn.ReLU(inplace=True),
#            nn.Dropout(0.3),  # Add dropout
#            nn.Linear(2048, 2048),  # Additional fully connected layer
#            nn.ReLU(inplace=True),  # Additional ReLU activation
            nn.Linear(2048, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Define transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize(224),
    #transforms.RandomRotation(45),  # Augmentation: Random rotation
    #transforms.RandomHorizontalFlip(),  # Augmentation: Random horizontal flip
    #transforms.CenterCrop(224),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Load the trained model
model = AlexNetBinary()  # Load your trained model here
model.load_state_dict(torch.load('alexnet_custom_20_epoch_v2.pth'))
model.eval()

# Load and preprocess the image
#image_path = 'Images/003847.jpg'  # Provide path to your test image
image_path = 'Images_Prediksi\wanita1.jpeg'
image = Image.open(image_path)
image_tensor = transform(image).unsqueeze(0)  # Add batch dimension

# Make prediction
with torch.no_grad():
    output = model(image_tensor)
    predicted = torch.round(torch.sigmoid(output))  # Round predictions to 0 or 1
    predicted_prob = torch.sigmoid(output).item()

# Print the prediction
predicted_class = 'Male' if predicted.item() == 1 else 'Female'
print("Predicted class:", predicted_class)
print("Predicted probability:", predicted_prob)

# Convert predicted probability to percentage
male_percentage = predicted_prob 
female_percentage = 1 - male_percentage

# Labels untuk sumbu x
labels = ['Male', 'Female']

# Data untuk sumbu y
sizes = [male_percentage, female_percentage]

# Warna untuk setiap bar
colors = ['lightblue', 'lightcoral']


# Plot the percentages
labels = ['Male', 'Female']
sizes = [male_percentage, female_percentage]
colors = ['lightblue', 'lightcoral']

# Display the image and prediction result
plt.figure(figsize=(8, 4))

# Display the image
plt.subplot(1, 2, 1)
img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.title('Test Image')

# Display the prediction result

plt.subplot(1, 2, 2)
plt.bar(labels, sizes, color=colors)
plt.title('Prediction Result')
plt.xlabel('Gender')
plt.ylabel('Probability')
plt.ylim([0, 1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 59
#      57 # Load the trained model
#      58 model = AlexNetBinary()  # Load your trained model here
# ---> 59 model.load_state_dict(torch.load('alexnet_custom_20_epoch_v2.pth'))
#      60 model.eval()
#      62 # Load and preprocess the image
#      63 #image_path = 'Images/003847.jpg'  # Provide path to your test image
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'alexnet_custom_20_epoch_v2.pth'
