# %%
# Alexnet 50 Epoch, training 80%, testing 20%
# Learning Rate 0.00001

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from PIL import Image
import pandas as pd
import os
import time
import matplotlib.pyplot as plt

# Define AlexNet model for binary classification with dropout
class AlexNetBinary(nn.Module):
    def __init__(self, num_classes=1):
        super(AlexNetBinary, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),  # Add dropout
            nn.Linear(256 * 6 * 6, 2048),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),  # Add dropout
            nn.Linear(2048, 2048),
            nn.ReLU(inplace=True),
            nn.Linear(2048, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Define dataset class
class CustomDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.dataframe = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 0])
        image = Image.open(img_name)
        label = int(self.dataframe.iloc[idx, 1])
        if label == -1:
            label = 0  # Change label -1 to 0 for consistency in the model
        if self.transform:
            image = self.transform(image)
        return image, label

# Load CSV file and define dataset
csv_file = 'clean_attribute_indra.csv'
root_dir = 'Images/'
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.RandomRotation(25),  # Augmentation: Random rotation
    transforms.RandomHorizontalFlip(),  # Augmentation: Random horizontal flip
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])
dataset = CustomDataset(csv_file=csv_file, root_dir=root_dir, transform=transform)

# Split dataset into train, validation, and test sets
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# Create data loaders for train and test sets
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Initialize the model, optimizer, and loss function
model = AlexNetBinary()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=0.00001)  # Lower learning rate
criterion = nn.BCEWithLogitsLoss()

# Training the model with validation
num_epochs = 50
train_loss_list = []
train_accuracy_list = []
val_loss_list = []
val_accuracy_list = []

for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_train_loss = 0.0
    correct_train = 0
    total_train = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.float().unsqueeze(1).to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_train_loss += loss.item()
        predicted_train = torch.round(torch.sigmoid(outputs))
        total_train += labels.size(0)
        correct_train += (predicted_train == labels).sum().item()
    
    train_loss_list.append(running_train_loss / len(train_loader))
    train_accuracy_list.append((correct_train / total_train) * 100)
    
    # Evaluate the model on test set
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.float().unsqueeze(1).to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            predicted_val = torch.round(torch.sigmoid(outputs))
            total_val += labels.size(0)
            correct_val += (predicted_val == labels).sum().item()
    
    val_loss_list.append(val_loss / len(test_loader))
    val_accuracy_list.append((correct_val / total_val) * 100)
    
    end_time = time.time()
    epoch_time = end_time - start_time
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {train_loss_list[-1]:.4f}, Train Accuracy: {train_accuracy_list[-1]:.2f}%, '
          f'Validation Loss: {val_loss_list[-1]:.4f}, Validation Accuracy: {val_accuracy_list[-1]:.2f}%, '
          f'Time per Epoch: {epoch_time:.2f} seconds')

# Plotting
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss', color='blue')
plt.plot(val_loss_list, label='Validation Loss', color='orange')
plt.title('Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracy_list, label='Train Accuracy', color='blue')
plt.plot(val_accuracy_list, label='Validation Accuracy', color='orange')
plt.title('Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Evaluate the model on test set
model.eval()
test_correct = 0
test_total = 0
test_loss = 0.0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.float().unsqueeze(1).to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        predicted = torch.round(torch.sigmoid(outputs))
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

print('Test Loss: {:.4f}, Test Accuracy: {:.2f}%'.format(test_loss / len(test_loader), (test_correct / test_total) * 100))

# Save the model
torch.save(model.state_dict(), 'alexnet_custom_50_epoch_rev2.pth')
# Out:
# Epoch [1/50], Train Loss: 0.6817, Train Accuracy: 57.83%, Validation Loss: 0.6639, Validation Accuracy: 60.30%, Time per Epoch: 21.23 seconds
# Epoch [2/50], Train Loss: 0.6597, Train Accuracy: 59.72%, Validation Loss: 0.6063, Validation Accuracy: 67.10%, Time per Epoch: 22.24 seconds
# Epoch [3/50], Train Loss: 0.6120, Train Accuracy: 65.90%, Validation Loss: 0.5623, Validation Accuracy: 70.50%, Time per Epoch: 23.71 seconds
# Epoch [4/50], Train Loss: 0.5740, Train Accuracy: 69.30%, Validation Loss: 0.5185, Validation Accuracy: 74.50%, Time per Epoch: 22.08 seconds
# Epoch [5/50], Train Loss: 0.5390, Train Accuracy: 72.35%, Validation Loss: 0.5142, Validation Accuracy: 75.40%, Time per Epoch: 21.57 seconds
# Epoch [6/50], Train Loss: 0.5058, Train Accuracy: 75.28%, Validation Loss: 0.4891, Validation Accuracy: 76.60%, Time per Epoch: 21.30 seconds
# Epoch [7/50], Train Loss: 0.4820, Train Accuracy: 77.18%, Validation Loss: 0.4454, Validation Accuracy: 80.00%, Time per Epoch: 21.93 seconds
# Epoch [8/50], Train Loss: 0.4622, Train Accuracy: 77.92%, Validation Loss: 0.4391, Validation Accuracy: 79.80%, Time per Epoch: 20.89 seconds
# Epoch [9/50], Train Loss: 0.4347, Train Accuracy: 79.80%, Validation Loss: 0.3976, Validation Accuracy: 82.20%, Time per Epoch: 20.83 seconds
# Epoch [10/50], Train Loss: 0.3967, Train Accuracy: 81.92%, Validation Loss: 0.3731, Validation Accuracy: 84.00%, Time per Epoch: 20.87 seconds
# Epoch [11/50], Train Loss: 0.3755, Train Accuracy: 83.65%, Validation Loss: 0.3530, Validation Accuracy: 84.20%, Time per Epoch: 20.80 seconds
# Epoch [12/50], Train Loss: 0.3405, Train Accuracy: 84.70%, Validation Loss: 0.3199, Validation Accuracy: 87.10%, Time per Epoch: 21.21 seconds
# Epoch [13/50], Train Loss: 0.3084, Train Accuracy: 86.55%, Validation Loss: 0.2919, Validation Accuracy: 87.80%, Time per Epoch: 21.02 seconds
# Epoch [14/50], Train Loss: 0.2838, Train Accuracy: 88.00%, Validation Loss: 0.2957, Validation Accuracy: 87.10%, Time per Epoch: 23.12 seconds
# Epoch [15/50], Train Loss: 0.2785, Train Accuracy: 88.48%, Validation Loss: 0.2880, Validation Accuracy: 89.00%, Time per Epoch: 22.22 seconds
# Epoch [16/50], Train Loss: 0.2596, Train Accuracy: 89.35%, Validation Loss: 0.2666, Validation Accuracy: 89.60%, Time per Epoch: 23.31 seconds
# Epoch [17/50], Train Loss: 0.2374, Train Accuracy: 90.20%, Validation Loss: 0.2692, Validation Accuracy: 89.60%, Time per Epoch: 23.73 seconds
# Epoch [18/50], Train Loss: 0.2305, Train Accuracy: 90.30%, Validation Loss: 0.2413, Validation Accuracy: 90.30%, Time per Epoch: 21.18 seconds
# Epoch [19/50], Train Loss: 0.2370, Train Accuracy: 89.85%, Validation Loss: 0.2479, Validation Accuracy: 90.00%, Time per Epoch: 21.18 seconds
# Epoch [20/50], Train Loss: 0.2162, Train Accuracy: 91.22%, Validation Loss: 0.2471, Validation Accuracy: 90.30%, Time per Epoch: 22.31 seconds
# Epoch [21/50], Train Loss: 0.2212, Train Accuracy: 90.95%, Validation Loss: 0.2351, Validation Accuracy: 90.60%, Time per Epoch: 22.12 seconds
# Epoch [22/50], Train Loss: 0.2069, Train Accuracy: 91.47%, Validation Loss: 0.2483, Validation Accuracy: 89.70%, Time per Epoch: 21.37 seconds
# Epoch [23/50], Train Loss: 0.2082, Train Accuracy: 91.30%, Validation Loss: 0.2517, Validation Accuracy: 90.00%, Time per Epoch: 21.64 seconds
# Epoch [24/50], Train Loss: 0.2037, Train Accuracy: 91.67%, Validation Loss: 0.2350, Validation Accuracy: 91.50%, Time per Epoch: 20.70 seconds
# Epoch [25/50], Train Loss: 0.1919, Train Accuracy: 92.45%, Validation Loss: 0.2309, Validation Accuracy: 90.80%, Time per Epoch: 22.04 seconds
# Epoch [26/50], Train Loss: 0.1903, Train Accuracy: 92.27%, Validation Loss: 0.2321, Validation Accuracy: 90.80%, Time per Epoch: 20.59 seconds
# Epoch [27/50], Train Loss: 0.1826, Train Accuracy: 92.73%, Validation Loss: 0.2211, Validation Accuracy: 91.50%, Time per Epoch: 21.54 seconds
# Epoch [28/50], Train Loss: 0.1777, Train Accuracy: 92.75%, Validation Loss: 0.2278, Validation Accuracy: 91.70%, Time per Epoch: 20.98 seconds
# Epoch [29/50], Train Loss: 0.1724, Train Accuracy: 93.35%, Validation Loss: 0.2642, Validation Accuracy: 89.50%, Time per Epoch: 20.38 seconds
# Epoch [30/50], Train Loss: 0.1693, Train Accuracy: 92.75%, Validation Loss: 0.2112, Validation Accuracy: 92.60%, Time per Epoch: 20.72 seconds
# Epoch [31/50], Train Loss: 0.1692, Train Accuracy: 93.17%, Validation Loss: 0.2252, Validation Accuracy: 91.70%, Time per Epoch: 21.34 seconds
# Epoch [32/50], Train Loss: 0.1695, Train Accuracy: 92.95%, Validation Loss: 0.2217, Validation Accuracy: 90.70%, Time per Epoch: 21.33 seconds
# Epoch [33/50], Train Loss: 0.1697, Train Accuracy: 93.40%, Validation Loss: 0.2105, Validation Accuracy: 92.30%, Time per Epoch: 20.88 seconds
# Epoch [34/50], Train Loss: 0.1582, Train Accuracy: 93.73%, Validation Loss: 0.2310, Validation Accuracy: 90.00%, Time per Epoch: 21.15 seconds
# Epoch [35/50], Train Loss: 0.1631, Train Accuracy: 93.60%, Validation Loss: 0.2314, Validation Accuracy: 92.10%, Time per Epoch: 19.83 seconds
# Epoch [36/50], Train Loss: 0.1506, Train Accuracy: 93.92%, Validation Loss: 0.1918, Validation Accuracy: 92.70%, Time per Epoch: 22.07 seconds
# Epoch [37/50], Train Loss: 0.1461, Train Accuracy: 93.90%, Validation Loss: 0.2113, Validation Accuracy: 92.80%, Time per Epoch: 21.38 seconds
# Epoch [38/50], Train Loss: 0.1512, Train Accuracy: 94.00%, Validation Loss: 0.2020, Validation Accuracy: 92.70%, Time per Epoch: 23.07 seconds
# Epoch [39/50], Train Loss: 0.1514, Train Accuracy: 93.85%, Validation Loss: 0.2044, Validation Accuracy: 92.50%, Time per Epoch: 22.45 seconds
# Epoch [40/50], Train Loss: 0.1510, Train Accuracy: 94.30%, Validation Loss: 0.2059, Validation Accuracy: 92.00%, Time per Epoch: 23.24 seconds
# Epoch [41/50], Train Loss: 0.1377, Train Accuracy: 94.47%, Validation Loss: 0.2221, Validation Accuracy: 92.00%, Time per Epoch: 24.60 seconds
# Epoch [42/50], Train Loss: 0.1412, Train Accuracy: 94.58%, Validation Loss: 0.1832, Validation Accuracy: 93.30%, Time per Epoch: 23.57 seconds
# Epoch [43/50], Train Loss: 0.1399, Train Accuracy: 94.58%, Validation Loss: 0.2211, Validation Accuracy: 92.70%, Time per Epoch: 27.26 seconds
# Epoch [44/50], Train Loss: 0.1332, Train Accuracy: 94.60%, Validation Loss: 0.2342, Validation Accuracy: 92.50%, Time per Epoch: 25.19 seconds
# Epoch [45/50], Train Loss: 0.1277, Train Accuracy: 95.03%, Validation Loss: 0.1899, Validation Accuracy: 92.60%, Time per Epoch: 23.31 seconds
# Epoch [46/50], Train Loss: 0.1242, Train Accuracy: 95.25%, Validation Loss: 0.2033, Validation Accuracy: 93.00%, Time per Epoch: 23.37 seconds
# Epoch [47/50], Train Loss: 0.1251, Train Accuracy: 95.33%, Validation Loss: 0.2101, Validation Accuracy: 92.60%, Time per Epoch: 24.89 seconds
# Epoch [48/50], Train Loss: 0.1225, Train Accuracy: 95.62%, Validation Loss: 0.2364, Validation Accuracy: 91.50%, Time per Epoch: 22.85 seconds
# Epoch [49/50], Train Loss: 0.1281, Train Accuracy: 94.92%, Validation Loss: 0.2019, Validation Accuracy: 92.20%, Time per Epoch: 23.17 seconds
# Epoch [50/50], Train Loss: 0.1256, Train Accuracy: 95.30%, Validation Loss: 0.2026, Validation Accuracy: 92.30%, Time per Epoch: 22.69 seconds
# Test Loss: 0.2100, Test Accuracy: 92.40%

# %%
import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt

# Define transform for image preprocessing
transform = transforms.Compose([
    transforms.Resize(224),
    #transforms.RandomRotation(45),  # Augmentation: Random rotation
    #transforms.RandomHorizontalFlip(),  # Augmentation: Random horizontal flip
    #transforms.CenterCrop(224),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Load the trained model
model = AlexNetBinary()  # Load your trained model here
model.load_state_dict(torch.load('alexnet_custom_50_epoch_rev2.pth'))
model.eval()

# Load and preprocess the image
#image_path = 'Images/003847.jpg'  # Provide path to your test image
image_path = 'Images_Prediksi\wanita5.jpeg'
image = Image.open(image_path)
image_tensor = transform(image).unsqueeze(0)  # Add batch dimension

# Make prediction
with torch.no_grad():
    output = model(image_tensor)
    predicted = torch.round(torch.sigmoid(output))  # Round predictions to 0 or 1
    predicted_prob = torch.sigmoid(output).item()

# Print the prediction
predicted_class = 'Male' if predicted.item() == 1 else 'Female'
print("Predicted class:", predicted_class)
print("Predicted probability:", predicted_prob)

# Convert predicted probability to percentage
male_percentage = predicted_prob 
female_percentage = 1 - male_percentage

# Labels untuk sumbu x
labels = ['Male', 'Female']

# Data untuk sumbu y
sizes = [male_percentage, female_percentage]

# Warna untuk setiap bar
colors = ['lightblue', 'lightcoral']


# Plot the percentages
labels = ['Male', 'Female']
sizes = [male_percentage, female_percentage]
colors = ['lightblue', 'lightcoral']

# Display the image and prediction result
plt.figure(figsize=(8, 4))

# Display the image
plt.subplot(1, 2, 1)
img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.title('Test Image')

# Display the prediction result

plt.subplot(1, 2, 2)
plt.bar(labels, sizes, color=colors)
plt.title('Prediction Result')
plt.xlabel('Gender')
plt.ylabel('Probability')
plt.ylim([0, 1])

plt.show()
# Out:
# Predicted class: Male
# Predicted probability: 0.9039146304130554
