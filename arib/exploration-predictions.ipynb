# %%
import pandas as pd
import os
import torch
import torchvision.transforms as transforms
from torchvision import models
from PIL import Image
from tensorflow.keras.models import load_model
# Out:
# 2024-03-10 01:07:40.860622: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-10 01:07:40.914816: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-10 01:07:40.914846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-10 01:07:40.916704: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-10 01:07:40.925433: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 01:07:41.957807: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the saved InceptionV3 model
saved_model = load_model("model_saved/inception-v3-30%-test-size-epoch-50.h5")

saved_model
# Out:
# 2024-03-10 01:07:45.707812: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.709956: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.710141: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.711698: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.711933: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.712103: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.895818: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.896468: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.896491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-10 01:07:45.896817: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-10 01:07:45.896848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5675 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
df = pd.read_csv('list_attribute.txt', delim_whitespace=True, index_col=0)
image_files = os.listdir('images/')
filtered_df = df[df.index.isin(image_files)]
train_files = os.listdir('train/')
test_files = os.listdir('test/')
test_df = filtered_df[filtered_df.index.isin(test_files)]

test_df
# Out:
# /tmp/ipykernel_8898/3425524605.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('list_attribute.txt', delim_whitespace=True, index_col=0)
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000166.jpg                 1               -1          -1               -1
# 000352.jpg                -1               -1           1                1
# 000414.jpg                 1               -1          -1               -1
# 000608.jpg                -1               -1          -1               -1
# 000798.jpg                -1               -1          -1                1
# ...                      ...              ...         ...              ...
# 201867.jpg                -1               -1          -1               -1
# 201956.jpg                 1                1          -1               -1
# 201989.jpg                -1               -1           1               -1
# 202200.jpg                -1               -1           1               -1
# 202276.jpg                -1               -1          -1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# 000166.jpg    -1     -1        -1         1          -1          -1  ...
# 000352.jpg    -1      1        -1         1          -1          -1  ...
# 000414.jpg    -1     -1        -1        -1          -1          -1  ...
# 000608.jpg    -1     -1        -1        -1          -1          -1  ...
# 000798.jpg    -1      1        -1         1          -1          -1  ...
# ...          ...    ...       ...       ...         ...         ...  ...
# 201867.jpg    -1     -1        -1         1          -1          -1  ...
# 201956.jpg    -1     -1         1        -1           1          -1  ...
# 201989.jpg    -1     -1        -1        -1          -1          -1  ...
# 202200.jpg    -1     -1         1        -1           1          -1  ...
# 202276.jpg    -1     -1        -1        -1          -1          -1  ...
#
#             Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# 000166.jpg          1       -1             -1         -1                -1
# 000352.jpg         -1        1             -1         -1                -1
# 000414.jpg         -1        1             -1         -1                -1
# 000608.jpg         -1        1              1         -1                -1
# 000798.jpg         -1        1             -1         -1                -1
# ...               ...      ...            ...        ...               ...
# 201867.jpg         -1        1             -1          1                 1
# 201956.jpg         -1       -1             -1         -1                -1
# 201989.jpg         -1        1              1         -1                -1
# 202200.jpg         -1        1             -1          1                -1
# 202276.jpg         -1       -1             -1          1                -1
#
#             Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  \
# 000166.jpg            1                -1                -1               -1
# 000352.jpg           -1                -1                -1               -1
# 000414.jpg           -1                -1                -1               -1
# 000608.jpg           -1                -1                -1               -1
# 000798.jpg           -1                -1                -1               -1
# ...                 ...               ...               ...              ...
# 201867.jpg           -1                -1                -1               -1
# 201956.jpg           -1                -1                -1               -1
# 201989.jpg           -1                 1                -1               -1
# 202200.jpg           -1                 1                -1               -1
# 202276.jpg           -1                -1                -1               -1
#
#             Young
# 000166.jpg     -1
# 000352.jpg      1
# 000414.jpg      1
# 000608.jpg     -1
# 000798.jpg     -1
# ...           ...
# 201867.jpg     -1
# 201956.jpg      1
# 201989.jpg      1
# 202200.jpg      1
# 202276.jpg      1
#
# [1500 rows x 40 columns]
